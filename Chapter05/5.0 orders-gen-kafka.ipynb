# %%
# Import the required modules
import random
import json
from kafka import KafkaProducer
import time

# using datetime module
import datetime;

# Define the bootstrap servers and the topic name
bootstrap_servers = "kafka:9092"
topic = "orders"

# Create a Kafka producer with JSON value serializer
producer = KafkaProducer(bootstrap_servers=bootstrap_servers)

# Define the product IDs and the quantities
product_ids = [1001, 1002, 1003, 1004, 1005]
quantities = [1, 2, 3, 4, 5]

# Define a function to generate random event data
def generate_orders():
    current_time = time.time()
    order_id = random.randint(100000, 999999)
    product_id = random.choice(product_ids)
    quantity = random.choice(quantities)
    timestamp = datetime.datetime.fromtimestamp(current_time).strftime("%m/%d/%Y, %H:%M:%S")
    
    # Create an order dictionary
    return {"order_id": order_id, "product_id": product_id, "quantity": quantity,"timestamp": timestamp}
# Loop to generate and send events
while True:
  # Generate a random event
  order = generate_orders()
  # Print the event to the console
  print(order)
  # Send the event to the Kafka topic
    
  producer.send(topic, value=json.dumps(order).encode('utf-8'))
  time.sleep(10)
# Out:
# {'order_id': 200860, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:43:44'}
# {'order_id': 246759, 'product_id': 1001, 'quantity': 1, 'timestamp': '02/04/2024, 18:43:54'}
# {'order_id': 470003, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/04/2024, 18:44:04'}
# {'order_id': 460339, 'product_id': 1004, 'quantity': 4, 'timestamp': '02/04/2024, 18:44:14'}
# {'order_id': 956474, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/04/2024, 18:44:24'}
# {'order_id': 916828, 'product_id': 1004, 'quantity': 2, 'timestamp': '02/04/2024, 18:44:34'}
# {'order_id': 685972, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:44:44'}
# {'order_id': 957820, 'product_id': 1002, 'quantity': 5, 'timestamp': '02/04/2024, 18:44:54'}
# {'order_id': 529140, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/04/2024, 18:45:04'}
# {'order_id': 961643, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/04/2024, 18:45:14'}
# {'order_id': 647079, 'product_id': 1005, 'quantity': 2, 'timestamp': '02/04/2024, 18:45:24'}
# {'order_id': 386682, 'product_id': 1005, 'quantity': 4, 'timestamp': '02/04/2024, 18:45:34'}
# {'order_id': 520885, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/04/2024, 18:45:44'}
# {'order_id': 988505, 'product_id': 1003, 'quantity': 4, 'timestamp': '02/04/2024, 18:45:54'}
# {'order_id': 906023, 'product_id': 1003, 'quantity': 4, 'timestamp': '02/04/2024, 18:46:04'}
# {'order_id': 894534, 'product_id': 1001, 'quantity': 5, 'timestamp': '02/04/2024, 18:46:14'}
# {'order_id': 562239, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:46:24'}
# {'order_id': 969351, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:46:35'}
# {'order_id': 403934, 'product_id': 1003, 'quantity': 4, 'timestamp': '02/04/2024, 18:51:25'}
# {'order_id': 354690, 'product_id': 1005, 'quantity': 5, 'timestamp': '02/04/2024, 18:51:35'}
# {'order_id': 555875, 'product_id': 1003, 'quantity': 1, 'timestamp': '02/04/2024, 18:51:45'}
# {'order_id': 412398, 'product_id': 1003, 'quantity': 4, 'timestamp': '02/04/2024, 18:51:55'}
# {'order_id': 796876, 'product_id': 1002, 'quantity': 1, 'timestamp': '02/04/2024, 18:52:05'}
# {'order_id': 289570, 'product_id': 1004, 'quantity': 2, 'timestamp': '02/04/2024, 18:52:15'}
# {'order_id': 793322, 'product_id': 1001, 'quantity': 1, 'timestamp': '02/04/2024, 18:52:25'}
# {'order_id': 757300, 'product_id': 1004, 'quantity': 5, 'timestamp': '02/04/2024, 18:52:35'}
# {'order_id': 400273, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/04/2024, 18:52:45'}
# {'order_id': 337793, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/04/2024, 18:52:55'}
# {'order_id': 197169, 'product_id': 1005, 'quantity': 5, 'timestamp': '02/04/2024, 18:53:05'}
# {'order_id': 191259, 'product_id': 1001, 'quantity': 3, 'timestamp': '02/04/2024, 18:53:15'}
# {'order_id': 403481, 'product_id': 1005, 'quantity': 5, 'timestamp': '02/04/2024, 18:53:25'}
# {'order_id': 793581, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:53:35'}
# {'order_id': 470687, 'product_id': 1004, 'quantity': 1, 'timestamp': '02/04/2024, 18:53:45'}
# {'order_id': 316597, 'product_id': 1001, 'quantity': 1, 'timestamp': '02/04/2024, 18:53:55'}
# {'order_id': 241655, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/04/2024, 18:54:05'}
# {'order_id': 618177, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/04/2024, 18:54:15'}
# {'order_id': 844727, 'product_id': 1004, 'quantity': 2, 'timestamp': '02/04/2024, 18:54:25'}
# {'order_id': 171810, 'product_id': 1004, 'quantity': 4, 'timestamp': '02/04/2024, 18:54:36'}
# {'order_id': 259748, 'product_id': 1001, 'quantity': 2, 'timestamp': '02/04/2024, 18:54:46'}
# {'order_id': 180702, 'product_id': 1004, 'quantity': 2, 'timestamp': '02/04/2024, 18:54:56'}
# {'order_id': 379166, 'product_id': 1002, 'quantity': 5, 'timestamp': '02/04/2024, 18:55:06'}
# {'order_id': 338981, 'product_id': 1005, 'quantity': 3, 'timestamp': '02/04/2024, 18:55:16'}
# {'order_id': 961750, 'product_id': 1003, 'quantity': 3, 'timestamp': '02/04/2024, 18:55:26'}
# {'order_id': 729756, 'product_id': 1001, 'quantity': 4, 'timestamp': '02/04/2024, 18:55:36'}
# {'order_id': 347129, 'product_id': 1003, 'quantity': 1, 'timestamp': '02/04/2024, 18:55:46'}

# %% [markdown]
# ###
